# %% [markdown]
# ## 存入MongoDB

# %%
from top_100 import crawling_movies
res = crawling_movies()
res
# Out:
# {1: {'ranking': 1,
#   'title': '霸王别姬',
#   'stars': '张国荣,张丰毅,巩俐',
#   'score': 9.5,
#   'release_time': '1993-01-01',
#   'img_url': 'https://p1.meituan.net/movie/20803f59291c47e1e116c11963ce019e68711.jpg'},
#  2: {'ranking': 2,
#   'title': '肖申克的救赎',
#   'stars': '蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿',
#   'score': 9.5,
#   'release_time': '1994-09-10',
#   'img_url': 'https://p0.meituan.net/movie/283292171619cdfd5b240c8fd093f1eb255670.jpg'},
#  3: {'ranking': 3,
#   'title': '罗马假日',
#   'stars': '格利高里·派克,奥黛丽·赫本,埃迪·艾伯特',
#   'score': 9.1,
#   'release_time': '1953-09-02',
#   'img_url': 'https://p0.meituan.net/movie/289f98ceaa8a0ae737d3dc01cd05ab052213631.jpg'},
#  4: {'ranking': 4,
#   'title': '这个杀手不太冷',
#   'stars': '让·雷诺,加里·奥德曼,娜塔莉·波特曼',
#   'score': 9.5,
#   'release_time': '1994-09-14',
#   'img_url': 'https://p1.meituan.net/movie/6bea9af4524dfbd0b668eaa7e187c3df767253.jpg'},
#  5: {'ranking': 5,
#   'title': '泰坦尼克号',
#   'stars': '莱昂纳多·迪卡普里奥,凯特·温丝莱特,比利·赞恩',
#   'score': 9.5,
#   'release_time': '1998-04-03',
#   'img_url': 'https://p1.meituan.net/movie/b607fba7513e7f15eab170aac1e1400d878112.jpg'},
#  6: {'ranking': 6,
#   'title': '唐伯虎点秋香',
#   'stars': '周星驰,巩俐,郑佩佩',
#   'score': 9.1,
#   'release_time': '1993-07-01',
#   'img_url': 'https://p0.meituan.net/movie/da64660f82b98cdc1b8a3804e69609e041108.jpg'},
#  7: {'ranking': 7,
#   'title': '魂断蓝桥',
#   'stars': '费雯·丽,罗伯特·泰勒,露塞尔·沃特森',
#   'score': 9.2,
#   'release_time': '1940-05-17',
#   'img_url': 'https://p0.meituan.net/movie/46c29a8b8d8424bdda7715e6fd779c66235684.jpg'},
#  8: {'ranking': 8,
#   'title': '乱世佳人',
#   'stars': '费雯·丽,克拉克·盖博,奥利维娅·德哈维兰',
#   'score': 9.1,
#   'release_time': '1939-12-15',
#   'img_url': 'https://p0.meituan.net/movie/223c3e186db3ab4ea3bb14508c709400427933.jpg'},
#  9: {'ranking': 9,
#   'title': '天空之城',
#   'stars': '寺田农,鹫尾真知子,龟山助清',
#   'score': 9.1,
#   'release_time': '1992-01-01',
#   'img_url': 'https://p1.meituan.net/movie/ba1ed511668402605ed369350ab779d6319397.jpg'},
#  10: {'ranking': 10,
#   'title': '辛德勒的名单',
#   'stars': '连姆·尼森,拉尔夫·费因斯,本·金斯利',
#   'score': 9.2,
#   'release_time': '1993-12-15',
#   'img_url': 'https://p0.meituan.net/movie/b0d986a8bf89278afbb19f6abaef70f31206570.jpg'},
#  11: {'ranking': 11,
#   'title': '喜剧之王',
#   'stars': '周星驰,莫文蔚,张柏芝',
#   'score': 9.1,
#   'release_time': '1999-02-13',
#   'img_url': 'https://p1.meituan.net/movie/18e3191039d5e71562477659301f04aa61905.jpg'},
#  12: {'ranking': 12,
#   'title': '大闹天宫',
#   'stars': '邱岳峰,毕克,富润生',
#   'score': 9.0,
#   'release_time': '1965-12-31',
#   'img_url': 'https://p1.meituan.net/movie/14a7b337e8063e3ce05a5993ed80176b74208.jpg'},
#  13: {'ranking': 13,
#   'title': '音乐之声',
#   'stars': '朱莉·安德鲁斯,克里斯托弗·普卢默,埃琳诺·帕克',
#   'score': 9.0,
#   'release_time': '1965-03-02',
#   'img_url': 'https://p1.meituan.net/movie/6bc004d57358ee6875faa5e9a1239140128550.jpg'},
#  14: {'ranking': 14,
#   'title': '春光乍泄',
#   'stars': '张国荣,梁朝伟,张震',
#   'score': 9.2,
#   'release_time': '1997-05-30',
#   'img_url': 'https://p0.meituan.net/movie/ae7245920d95c03765fe1615f3a1fe3865785.jpg'},
#  15: {'ranking': 15,
#   'title': '剪刀手爱德华',
#   'stars': '约翰尼·德普,薇诺娜·瑞德,黛安·韦斯特',
#   'score': 8.8,
#   'release_time': '1990-12-06',
#   'img_url': 'https://p1.meituan.net/movie/6a964e9cee699267053bd6a4bf6f2671195394.jpg'},
#  16: {'ranking': 16,
#   'title': '美丽人生',
#   'stars': '罗伯托·贝尼尼,尼可莱塔·布拉斯基,乔治·坎塔里尼',
#   'score': 9.3,
#   'release_time': '1997-12-20',
#   'img_url': 'https://p0.meituan.net/movie/43d259ecbcd53e8bbe902632772281d6327525.jpg'},
#  17: {'ranking': 17,
#   'title': '海上钢琴师',
#   'stars': '蒂姆·罗斯,普路特·泰勒·文斯,比尔·努恩',
#   'score': 9.2,
#   'release_time': '1998-10-28',
#   'img_url': 'https://p0.meituan.net/movie/2bbaa395c825920fac397706369746e4300686.jpg'},
#  18: {'ranking': 18,
#   'title': '黑客帝国',
#   'stars': '基努·里维斯,凯瑞-安·莫斯,劳伦斯·菲什伯恩',
#   'score': 9.0,
#   'release_time': '2000-01-14',
#   'img_url': 'https://p1.meituan.net/movie/ad974d3527879f00be2eec29135118163728582.jpg'},
#  19: {'ranking': 19,
#   'title': '指环王3：王者无敌',
#   'stars': '伊莱贾·伍德,伊恩·麦克莱恩,丽芙·泰勒',
#   'score': 9.2,
#   'release_time': '2004-03-15',
#   'img_url': 'https://p0.meituan.net/movie/932bdfbef5be3543e6b136246aeb99b8123736.jpg'},
#  20: {'ranking': 20,
#   'title': '哈利·波特与魔法石',
#   'stars': '丹尼尔·雷德克里夫,鲁伯特·格林特,艾玛·沃特森',
#   'score': 9.1,
#   'release_time': '2002-01-26',
#   'img_url': 'https://p1.meituan.net/movie/aacb9ed2a6601bfe515ef0970add1715623792.jpg'},
#  21: {'ranking': 21,
#   'title': '蝙蝠侠：黑暗骑士',
#   'stars': '克里斯蒂安·贝尔,希斯·莱杰,阿伦·伊克哈特',
#   'score': 9.3,
#   'release_time': '2008-07-18',
#   'img_url': 'https://p0.meituan.net/movie/09658109acfea0e248a63932337d8e6a4268980.jpg'},
#  22: {'ranking': 22,
#   'title': '楚门的世界',
#   'stars': '金·凯瑞,劳拉·琳妮,诺亚·艾默里奇',
#   'score': 8.9,
#   'release_time': '1998-06-01',
#   'img_url': 'https://p0.meituan.net/movie/8959888ee0c399b0fe53a714bc8a5a17460048.jpg'},
#  23: {'ranking': 23,
#   'title': '加勒比海盗',
#   'stars': '约翰尼·德普,凯拉·奈特莉,奥兰多·布鲁姆',
#   'score': 8.9,
#   'release_time': '2003-11-21',
#   'img_url': 'https://p0.meituan.net/movie/b05b94b28eca53f325ae8d807fcd4ce01798036.jpg'},
#  24: {'ranking': 24,
#   'title': '射雕英雄传之东成西就',
#   'stars': '张国荣,梁朝伟,张学友',
#   'score': 8.9,
#   'release_time': '1993-02-05',
#   'img_url': 'https://p1.meituan.net/movie/53b6f0b66882a53b08896c92076515a8236400.jpg'},
#  25: {'ranking': 25,
#   'title': '无间道',
#   'stars': '刘德华,梁朝伟,黄秋生',
#   'score': 9.1,
#   'release_time': '2003-09-05',
#   'img_url': 'https://p0.meituan.net/movie/606de8f394d40dbcbb9b87943fec71a2130408.jpg'},
#  26: {'ranking': 26,
#   'title': '教父2',
#   'stars': '阿尔·帕西诺,罗伯特·德尼罗,黛安·基顿',
#   'score': 9.0,
#   'release_time': '1974-12-12',
#   'img_url': 'https://p0.meituan.net/movie/bb1dee5e0b25889a2410211c1d5010ae190824.jpg'},
#  27: {'ranking': 27,
#   'title': '机器人总动员',
#   'stars': '本·贝尔特,艾丽莎·奈特,杰夫·格尔林',
#   'score': 9.3,
#   'release_time': '2008-06-27',
#   'img_url': 'https://p0.meituan.net/movie/267dd2483f0fb57081474c00fbea38451415571.jpg'},
#  28: {'ranking': 28,
#   'title': '指环王1：护戒使者',
#   'stars': '伊莱贾·伍德,伊恩·麦克莱恩,丽芙·泰勒',
#   'score': 9.0,
#   'release_time': '2002-04-04',
#   'img_url': 'https://p1.meituan.net/movie/dd08154878aac7c8c649fe3eeb8ccd0a2498277.jpg'},
#  29: {'ranking': 29,
#   'title': '指环王2：双塔奇兵',
#   'stars': '伊莱贾·伍德,伊恩·麦克莱恩,丽芙·泰勒',
#   'score': 9.1,
#   'release_time': '2003-04-25',
#   'img_url': 'https://p0.meituan.net/movie/02bb9fd161c05bad6089133098efcdb5546589.jpg'},
#  30: {'ranking': 30,
#   'title': '狮子王',
#   'stars': '马修·布罗德里克,尼基塔·卡兰姆,詹姆斯·厄尔·琼斯',
#   'score': 8.8,
#   'release_time': '1995-07-15',
#   'img_url': 'https://p0.meituan.net/movie/27b76fe6cf3903f3d74963f70786001e1438406.jpg'},
#  31: {'ranking': 31,
#   'title': '活着',
#   'stars': '葛优,巩俐,牛犇',
#   'score': 9.0,
#   'release_time': '1994-05-18',
#   'img_url': 'https://p0.meituan.net/movie/4c41068ef7608c1d4fbfbe6016e589f7204391.jpg'},
#  32: {'ranking': 32,
#   'title': '天堂电影院',
#   'stars': '菲利浦·诺瓦雷,赛尔乔·卡斯特利托,蒂兹亚娜·罗达托',
#   'score': 9.2,
#   'release_time': '1988-11-17',
#   'img_url': 'https://p0.meituan.net/movie/76fc92cfa6c8f2959431b8aa604ef7ae126414.jpg'},
#  33: {'ranking': 33,
#   'title': '拯救大兵瑞恩',
#   'stars': '汤姆·汉克斯,马特·达蒙,汤姆·塞兹摩尔',
#   'score': 8.9,
#   'release_time': '1998-11-13',
#   'img_url': 'https://p1.meituan.net/movie/a2a287c77415dc1f85b04d288f7d63ab1089754.jpg'},
#  34: {'ranking': 34,
#   'title': '哈尔的移动城堡',
#   'stars': '倍赏千惠子,木村拓哉,美轮明宏',
#   'score': 9.0,
#   'release_time': '2004-11-20',
#   'img_url': 'https://p0.meituan.net/movie/0127b451d5b8f0679c6f81c8ed414bb2432442.jpg'},
#  35: {'ranking': 35,
#   'title': '忠犬八公的故事',
#   'stars': 'Forest,理查·基尔,琼·艾伦',
#   'score': 9.3,
#   'release_time': '2010-03-12',
#   'img_url': 'https://p0.meituan.net/movie/7787c10ad5e95b03cf83ef9473500d8e282796.jpg'},
#  36: {'ranking': 36,
#   'title': '疯狂原始人',
#   'stars': '尼古拉斯·凯奇,艾玛·斯通,瑞安·雷诺兹',
#   'score': 9.5,
#   'release_time': '2013-04-20',
#   'img_url': 'https://p1.meituan.net/movie/bc022b86345c643ca21d759166f77a553679589.jpg'},
#  37: {'ranking': 37,
#   'title': '盗梦空间',
#   'stars': '莱昂纳多·迪卡普里奥,渡边谦,约瑟夫·高登-莱维特',
#   'score': 9.2,
#   'release_time': '2010-09-01',
#   'img_url': 'https://p1.meituan.net/movie/2f344a9f9575edbcae9f0abe0578bc90339773.jpg'},
#  38: {'ranking': 38,
#   'title': '幽灵公主',
#   'stars': '松田洋治,石田百合子,田中裕子',
#   'score': 8.9,
#   'release_time': '1998-05-01',
#   'img_url': 'https://p0.meituan.net/movie/a08f65e6cb50fab32df5da69ff116f593095363.jpg'},
#  39: {'ranking': 39,
#   'title': '东邪西毒',
#   'stars': '张国荣,梁朝伟,刘嘉玲',
#   'score': 8.8,
#   'release_time': '1994-09-17',
#   'img_url': 'https://p1.meituan.net/movie/7e471a9171a410ebc9413b2f1de67afc130067.jpg'},
#  40: {'ranking': 40,
#   'title': '阿凡达',
#   'stars': '萨姆·沃辛顿,佐伊·索尔达娜,米歇尔·罗德里格兹',
#   'score': 9.0,
#   'release_time': '2010-01-04',
#   'img_url': 'https://p1.meituan.net/movie/91f575ec93f019f428d1f33e3ceca7c5115495.jpg'},
#  41: {'ranking': 41,
#   'title': '搏击俱乐部',
#   'stars': '爱德华·哈里森·诺顿,布拉德·皮特,海伦娜·伯翰·卡特',
#   'score': 8.8,
#   'release_time': '1999-10-15',
#   'img_url': 'https://p0.meituan.net/movie/b3defc07dfaa1b6f5b74852ce38a3f8f242792.jpg'},
#  42: {'ranking': 42,
#   'title': '风之谷',
#   'stars': '岛本须美,永井一郎,坂本千夏',
#   'score': 8.9,
#   'release_time': '1992-01-01',
#   'img_url': 'https://p0.meituan.net/movie/4f9638ba234c3fb673f23a09968db875371576.jpg'},
#  43: {'ranking': 43,
#   'title': 'V字仇杀队',
#   'stars': '娜塔莉·波特曼,雨果·维文,斯蒂芬·瑞',
#   'score': 8.8,
#   'release_time': '2006-03-17',
#   'img_url': 'https://p1.meituan.net/movie/06ec3c1c647942b1e40bca84036014e9490863.jpg'},
#  44: {'ranking': 44,
#   'title': '十二怒汉',
#   'stars': '亨利·方达,李·科布,马丁·鲍尔萨姆',
#   'score': 9.1,
#   'release_time': '1957-04-13',
#   'img_url': 'https://p0.meituan.net/movie/df15efd261060d3094a73ef679888d4f238149.jpg'},
#  45: {'ranking': 45,
#   'title': '当幸福来敲门',
#   'stars': '威尔·史密斯,贾登·史密斯,坦迪·牛顿',
#   'score': 8.9,
#   'release_time': '2008-01-17',
#   'img_url': 'https://p1.meituan.net/movie/5896de3c1474277730e321c9b1db04a9205644.jpg'},
#  46: {'ranking': 46,
#   'title': '驯龙高手',
#   'stars': '杰伊·巴鲁切尔,杰拉德·巴特勒,亚美莉卡·费雷拉',
#   'score': 9.0,
#   'release_time': '2010-05-14',
#   'img_url': 'https://p0.meituan.net/movie/b0d97e4158b47d653d7a81d66f7dd3092146907.jpg'},
#  47: {'ranking': 47,
#   'title': '速度与激情5',
#   'stars': '范·迪塞尔,保罗·沃克,道恩·强森',
#   'score': 9.2,
#   'release_time': '2011-05-12',
#   'img_url': 'https://p0.meituan.net/movie/845ce32778a1b3f258de089f91a3979b5766154.jpg'},
#  48: {'ranking': 48,
#   'title': '放牛班的春天',
#   'stars': '热拉尔·朱尼奥,让-巴蒂斯特·莫尼耶,玛丽·布奈尔',
#   'score': 8.8,
#   'release_time': '2004-10-16',
#   'img_url': 'https://p0.meituan.net/movie/70de97ebb6b5251ecb7c3f6d7a782a7f189340.jpg'},
#  49: {'ranking': 49,
#   'title': '勇敢的心',
#   'stars': '梅尔·吉布森,苏菲·玛索,帕特里克·麦高汉',
#   'score': 8.8,
#   'release_time': '1995-05-24',
#   'img_url': 'https://p1.meituan.net/movie/f8e9d5a90224746d15dfdbd53d4fae3d209420.jpg'},
#  50: {'ranking': 50,
#   'title': '神偷奶爸',
#   'stars': '史蒂夫·卡瑞尔,杰森·席格尔,拉塞尔·布兰德',
#   'score': 9.0,
#   'release_time': '2010-07-09',
#   'img_url': 'https://p0.meituan.net/movie/85c2bfba6025bfbfb53291ae5924c215308805.jpg'},
#  51: {'ranking': 51,
#   'title': '飞屋环游记',
#   'stars': '爱德华·阿斯纳,乔丹·长井,鲍勃·彼德森',
#   'score': 8.9,
#   'release_time': '2009-08-04',
#   'img_url': 'https://p0.meituan.net/movie/47dd790e19dad72b50580641de5608c5199014.jpg'},
#  52: {'ranking': 52,
#   'title': '闻香识女人',
#   'stars': '阿尔·帕西诺,克里斯·奥唐纳,加布里埃尔·安瓦尔',
#   'score': 8.8,
#   'release_time': '1992-12-23',
#   'img_url': 'https://p1.meituan.net/movie/8d7b0b902afd4ec1a3dd7a9c6149463c187734.jpg'},
#  53: {'ranking': 53,
#   'title': '三傻大闹宝莱坞',
#   'stars': '阿米尔·汗,黄渤,卡琳娜·卡普',
#   'score': 9.1,
#   'release_time': '2011-12-08',
#   'img_url': 'https://p1.meituan.net/movie/ca4a128a5a54d5b5e35ceba622636c831810197.jpg'},
#  54: {'ranking': 54,
#   'title': '断背山',
#   'stars': '希斯·莱杰,杰克·吉伦哈尔,米歇尔·威廉姆斯',
#   'score': 9.0,
#   'release_time': '2006-01-13',
#   'img_url': 'https://p0.meituan.net/movie/e71affe126eeb4f8bfcc738cbddeebc8288766.jpg'},
#  55: {'ranking': 55,
#   'title': '黑客帝国3：矩阵革命',
#   'stars': '基努·里维斯,雨果·维文,凯瑞-安·莫斯',
#   'score': 8.8,
#   'release_time': '2003-11-05',
#   'img_url': 'https://p0.meituan.net/movie/2e383b5f5f306f10f9f26d9f1c28cf1d825537.jpg'},
#  56: {'ranking': 56,
#   'title': '少年派的奇幻漂流',
#   'stars': '苏拉·沙玛,伊尔凡·可汗,塔布',
#   'score': 9.1,
#   'release_time': '2012-11-22',
#   'img_url': 'https://p0.meituan.net/movie/34998e31c6d07475f1add6b8b16fd21d192579.jpg'},
#  57: {'ranking': 57,
#   'title': '末代皇帝',
#   'stars': '尊龙,陈冲,彼得·奥图尔',
#   'score': 8.8,
#   'release_time': '1987-10-23',
#   'img_url': 'https://p1.meituan.net/movie/21b9211eb1094af360842472018db634286646.jpg'},
#  58: {'ranking': 58,
#   'title': '鬼子来了',
#   'stars': '姜文,姜宏波,陈强',
#   'score': 8.9,
#   'release_time': '2000-05-12',
#   'img_url': 'https://p1.meituan.net/movie/0b507aa44c4dfbbcc91949b69b1b39a168922.jpg'},
#  59: {'ranking': 59,
#   'title': '大话西游之月光宝盒',
#   'stars': '周星驰,莫文蔚,吴孟达',
#   'score': 9.6,
#   'release_time': '2014-10-24',
#   'img_url': 'https://p0.meituan.net/movie/92eb862c42c49f8e41e459c369c4512b226610.jpg'},
#  60: {'ranking': 60,
#   'title': '怦然心动',
#   'stars': '玛德琳·卡罗尔,卡兰·麦克奥利菲,艾丹·奎因',
#   'score': 8.9,
#   'release_time': '2010-08-06',
#   'img_url': 'https://p0.meituan.net/movie/15f1ac49b6d1ff7b71207672993ed6901536456.jpg'},
#  61: {'ranking': 61,
#   'title': '致命魔术',
#   'stars': '休·杰克曼,克里斯蒂安·贝尔,迈克尔·凯恩',
#   'score': 8.8,
#   'release_time': '2006-10-20',
#   'img_url': 'https://p1.meituan.net/movie/75c0d3eb584be030a01f2e26741a8f41251454.jpg'},
#  62: {'ranking': 62,
#   'title': '美丽心灵',
#   'stars': '罗素·克洛,詹妮弗·康纳利,艾德·哈里斯',
#   'score': 8.8,
#   'release_time': '2001-12-21',
#   'img_url': 'https://p0.meituan.net/movie/7b7d1f8aa36d7a15463ce6942708a1a7265296.jpg'},
#  63: {'ranking': 63,
#   'title': '无敌破坏王',
#   'stars': '约翰·C·赖利,萨拉·西尔弗曼,简·林奇',
#   'score': 9.1,
#   'release_time': '2012-11-06',
#   'img_url': 'https://p0.meituan.net/movie/fcc17667b8343131101eeb4c67d90bf9150883.jpg'},
#  64: {'ranking': 64,
#   'title': '哈利·波特与死亡圣器（下）',
#   'stars': '丹尼尔·雷德克里夫,鲁伯特·格林特,艾玛·沃特森',
#   'score': 9.0,
#   'release_time': '2011-08-04',
#   'img_url': 'https://p1.meituan.net/movie/bb0eca029cd25329776a4549b3fbe262924727.jpg'},
#  65: {'ranking': 65,
#   'title': '倩女幽魂',
#   'stars': '张国荣,王祖贤,午马',
#   'score': 9.2,
#   'release_time': '2011-04-30',
#   'img_url': 'https://p1.meituan.net/movie/96d98200d2afb4b87ff189f9c15b6545568339.jpg'},
#  66: {'ranking': 66,
#   'title': '夜访吸血鬼',
#   'stars': '汤姆·克鲁斯,布拉德·皮特,克尔斯滕·邓斯特',
#   'score': 8.8,
#   'release_time': '1994-11-11',
#   'img_url': 'https://p0.meituan.net/movie/7ec873ba943f13e3c63789d899bd0e23256871.jpg'},
#  67: {'ranking': 67,
#   'title': '蝙蝠侠：黑暗骑士崛起',
#   'stars': '克里斯蒂安·贝尔,迈克尔·凯恩,加里·奥德曼',
#   'score': 8.9,
#   'release_time': '2012-08-27',
#   'img_url': 'https://p1.meituan.net/movie/96bb58f3e9d213fb0438987d16d27561379209.jpg'},
#  68: {'ranking': 68,
#   'title': '钢琴家',
#   'stars': '艾德里安·布洛迪,艾米莉娅·福克斯,米哈乌·热布罗夫斯基',
#   'score': 8.8,
#   'release_time': '2002-09-25',
#   'img_url': 'https://p1.meituan.net/movie/484171372de45945e8bbbcc97db57e09136701.jpg'},
#  69: {'ranking': 69,
#   'title': '本杰明·巴顿奇事',
#   'stars': '布拉德·皮特,凯特·布兰切特,塔拉吉·P·汉森',
#   'score': 8.8,
#   'release_time': '2008-12-25',
#   'img_url': 'https://p0.meituan.net/movie/2526f77c650bf7cf3d5ee2dccdeac332244951.jpg'},
#  70: {'ranking': 70,
#   'title': '甜蜜蜜',
#   'stars': '黎明,张曼玉,曾志伟',
#   'score': 9.2,
#   'release_time': '2015-02-13',
#   'img_url': 'https://p1.meituan.net/movie/0b0d45b58946078dd24d4945dd6be3b51329411.jpg'},
#  71: {'ranking': 71,
#   'title': '初恋这件小事',
#   'stars': '马里奥·毛瑞尔,平采娜·乐维瑟派布恩,阿查拉那·阿瑞亚卫考',
#   'score': 8.8,
#   'release_time': '2012-06-05',
#   'img_url': 'https://p1.meituan.net/movie/7ed07b8ea8c0e0d0c7b685d20e3ec64e232004.jpg'},
#  72: {'ranking': 72,
#   'title': '触不可及',
#   'stars': '弗朗索瓦·克鲁塞,奥玛·希,安娜·勒尼',
#   'score': 9.1,
#   'release_time': '2011-11-02',
#   'img_url': 'https://p1.meituan.net/movie/1e700e53e4fe29dd5942381bb353c8532239179.jpg'},
#  73: {'ranking': 73,
#   'title': '新龙门客栈',
#   'stars': '张曼玉,梁家辉,甄子丹',
#   'score': 8.8,
#   'release_time': '2012-02-24',
#   'img_url': 'https://p1.meituan.net/movie/7833126c8c21a11571bb52fbdece0acb811449.jpg'},
#  74: {'ranking': 74,
#   'title': '熔炉',
#   'stars': '孔刘,郑有美,金智英',
#   'score': 8.8,
#   'release_time': '2011-09-22',
#   'img_url': 'https://p1.meituan.net/movie/2a0783b4fd95566568f24adfad2181bb5392280.jpg'},
#  75: {'ranking': 75,
#   'title': '大话西游之大圣娶亲',
#   'stars': '周星驰,朱茵,莫文蔚',
#   'score': 8.8,
#   'release_time': '2014-10-24',
#   'img_url': 'https://p1.meituan.net/movie/dc2246233a6f5ac1e34c7176b602c8ca174557.jpg'},
#  76: {'ranking': 76,
#   'title': '小鞋子',
#   'stars': '默罕默德·阿米尔·纳吉,Kamal Mirkarimi,Behzad Rafi',
#   'score': 9.0,
#   'release_time': '1999-01-22',
#   'img_url': 'https://p1.meituan.net/movie/135c612860fae899df2220149664d97a173555.jpg'},
#  77: {'ranking': 77,
#   'title': '教父',
#   'stars': '马龙·白兰度,阿尔·帕西诺,詹姆斯·肯恩',
#   'score': 9.3,
#   'release_time': '2015-04-18',
#   'img_url': 'https://p0.meituan.net/movie/1199dc6273680f175fd9b06c9c36d08a219658.jpg'},
#  78: {'ranking': 78,
#   'title': '素媛',
#   'stars': '李来,薛耿求,严志媛',
#   'score': 9.1,
#   'release_time': '2013-10-02',
#   'img_url': 'https://p0.meituan.net/movie/19653e8af59cf473cd40f9ccc0658d93692304.jpg'},
#  79: {'ranking': 79,
#   'title': '萤火之森',
#   'stars': '内山昂辉,佐仓绫音,后藤弘树',
#   'score': 9.0,
#   'release_time': '2011-09-17',
#   'img_url': 'https://p0.meituan.net/movie/5420be40e3b755ffe04779b9b199e935256906.jpg'},
#  80: {'ranking': 80,
#   'title': '穿条纹睡衣的男孩',
#   'stars': '阿沙·巴特菲尔德,维拉·法梅加,大卫·休里斯',
#   'score': 9.0,
#   'release_time': '2008-09-12',
#   'img_url': 'https://p1.meituan.net/movie/d5970e36c8868a4b746c80f3b3f8a404174615.jpg'},
#  81: {'ranking': 81,
#   'title': '窃听风暴',
#   'stars': '乌尔里希·穆埃,塞巴斯蒂安·科赫,马蒂娜·格德克',
#   'score': 9.0,
#   'release_time': '2006-03-23',
#   'img_url': 'https://p0.meituan.net/movie/3985eaf3858bea0f2a3d966bf7ee2103178217.jpg'},
#  82: {'ranking': 82,
#   'title': '时空恋旅人',
#   'stars': '瑞秋·麦克亚当斯,多姆纳尔·格里森,比尔·奈伊',
#   'score': 8.9,
#   'release_time': '2013-09-04',
#   'img_url': 'https://p0.meituan.net/movie/4abc8c932cfacfc0089e2883765d02d1295222.jpg'},
#  83: {'ranking': 83,
#   'title': '7号房的礼物',
#   'stars': '柳承龙,郑镇荣,朴信惠',
#   'score': 8.9,
#   'release_time': '2013-01-23',
#   'img_url': 'https://p1.meituan.net/movie/6a6e74b2c289f9fa4433dd2dc04a7741331638.jpg'},
#  84: {'ranking': 84,
#   'title': '恐怖直播',
#   'stars': '河正宇,李璟荣,李大为',
#   'score': 8.8,
#   'release_time': '2013-07-31',
#   'img_url': 'https://p0.meituan.net/movie/b5ff0216e689b3fcc065590c48cd5105255305.jpg'},
#  85: {'ranking': 85,
#   'title': '海豚湾',
#   'stars': '里克·奥巴瑞,路易·西霍尤斯,哈迪·琼斯',
#   'score': 8.9,
#   'release_time': '2009-07-31',
#   'img_url': 'https://p0.meituan.net/movie/7373dbba07b50ce6f24336edb96b2ea4271536.jpg'},
#  86: {'ranking': 86,
#   'title': '忠犬八公物语',
#   'stars': '仲代达矢,春川真澄,井川比佐志',
#   'score': 9.0,
#   'release_time': '1987-08-01',
#   'img_url': 'https://p1.meituan.net/movie/c835b3588d0061ed3b992388a0a96f15160913.jpg'},
#  87: {'ranking': 87,
#   'title': '上帝之城',
#   'stars': '亚历桑德雷·罗德里格斯,艾莉丝·布拉加,莱安德鲁·菲尔米诺',
#   'score': 8.9,
#   'release_time': '2002-08-30',
#   'img_url': 'https://p1.meituan.net/movie/b553d13f30100db731ab6cf45668e52d94703.jpg'},
#  88: {'ranking': 88,
#   'title': '美国往事',
#   'stars': '罗伯特·德尼罗,詹姆斯·伍兹,伊丽莎白·麦戈文',
#   'score': 9.1,
#   'release_time': '2015-04-23',
#   'img_url': 'https://p1.meituan.net/movie/92198a6fc8c3f5d13aa1bdf203572c0f99438.jpg'},
#  89: {'ranking': 89,
#   'title': '七武士',
#   'stars': '三船敏郎,志村乔,千秋实',
#   'score': 9.1,
#   'release_time': '1954-04-26',
#   'img_url': 'https://p1.meituan.net/movie/4ffca83fd972f71e291f8ea8d78a4b58594878.jpg'},
#  90: {'ranking': 90,
#   'title': '完美的世界',
#   'stars': '凯文·科斯特纳,克林特·伊斯特伍德,T·J·劳瑟',
#   'score': 8.9,
#   'release_time': '1993-11-24',
#   'img_url': 'https://p1.meituan.net/movie/30310858fdab34c7a17cfd7ec8ad8bfc112201.jpg'},
#  91: {'ranking': 91,
#   'title': '一一',
#   'stars': '吴念真,金燕玲,李凯莉',
#   'score': 8.9,
#   'release_time': '2000-09-20',
#   'img_url': 'https://p1.meituan.net/movie/2c0a5fedf4b43d142121b91c6ccabe1b59051.jpg'},
#  92: {'ranking': 92,
#   'title': '英雄本色',
#   'stars': '狄龙,张国荣,周润发',
#   'score': 9.2,
#   'release_time': '2017-11-17',
#   'img_url': 'https://p0.meituan.net/movie/3e5f5f3aa4b7e5576521e26c2c7c894d253975.jpg'},
#  93: {'ranking': 93,
#   'title': '阿飞正传',
#   'stars': '张国荣,张曼玉,刘德华',
#   'score': 8.8,
#   'release_time': '2018-06-25',
#   'img_url': 'https://p0.meituan.net/movie/885fc379c614a2b4175587b95ac98eb95045650.jpg'},
#  94: {'ranking': 94,
#   'title': '爱·回家',
#   'stars': '俞承豪,金艺芬,童孝熙',
#   'score': 9.0,
#   'release_time': '2002-04-05',
#   'img_url': 'https://p1.meituan.net/movie/36a893c53a13f9bb934071b86ae3b5c492427.jpg'},
#  95: {'ranking': 95,
#   'title': '海洋',
#   'stars': '雅克·贝汉,姜文,兰斯洛特·佩林',
#   'score': 9.0,
#   'release_time': '2011-08-12',
#   'img_url': 'https://p0.meituan.net/movie/0018b57299d0d4540330a31244c880a9112971.jpg'},
#  96: {'ranking': 96,
#   'title': '我爱你',
#   'stars': '宋在浩,李顺才,尹秀晶',
#   'score': 9.0,
#   'release_time': '2011-02-17',
#   'img_url': 'https://p1.meituan.net/movie/ed50b58bf636d207c56989872a91f4cf305138.jpg'},
#  97: {'ranking': 97,
#   'title': '黄金三镖客',
#   'stars': '克林特·伊斯特伍德,李·范·克里夫,埃里·瓦拉赫',
#   'score': 8.9,
#   'release_time': '1966-12-23',
#   'img_url': 'https://p0.meituan.net/movie/cd18ed2c5cda9e71e17e5e6ef61ced172912303.jpg'},
#  98: {'ranking': 98,
#   'title': '迁徙的鸟',
#   'stars': '雅克·贝汉,Philippe Labro',
#   'score': 9.1,
#   'release_time': '2001-12-12',
#   'img_url': 'https://p1.meituan.net/movie/a1634f4e49c8517ae0a3e4adcac6b0dc43994.jpg'},
#  99: {'ranking': 99,
#   'title': '龙猫',
#   'stars': '秦岚,糸井重里,岛本须美',
#   'score': 9.1,
#   'release_time': '2018-12-14',
#   'img_url': 'https://p0.meituan.net/movie/c304c687e287c7c2f9e22cf78257872d277201.jpg'},
#  100: {'ranking': 100,
#   'title': '千与千寻',
#   'stars': '柊瑠美,周冬雨,入野自由',
#   'score': 9.3,
#   'release_time': '2019-06-21',
#   'img_url': 'https://p0.meituan.net/movie/30b20139e68c46d02e0893277d633b701292458.jpg'}}

# %%
def load_config():
    import json
    with open("config.json") as config:
        return json.load(config)

# %%
def mongo_db(db_name):
    from pymongo import MongoClient
    client = MongoClient(f'{load_config()["host"]}:27017')
    mongo = client[db_name]
    return mongo


mongo = mongo_db('maoyan')

# %% [markdown]
# MongoDB插入数据之后，每个元素会增加`_id`的字段，为了后面继续用原始结果，MongoDB入库之前，将数据深拷贝一份。

# %%
import copy
res_deep_copy = copy.deepcopy(res)
list_to_mongo = [res_deep_copy[i] for i in res_deep_copy]
list_to_mongo[0]
# Out:
# {'ranking': 1,
#  'title': '霸王别姬',
#  'stars': '张国荣,张丰毅,巩俐',
#  'score': 9.5,
#  'release_time': '1993-01-01',
#  'img_url': 'https://p1.meituan.net/movie/20803f59291c47e1e116c11963ce019e68711.jpg'}

# %%
res_deep_copy[1]
# Out:
# {'ranking': 1,
#  'title': '霸王别姬',
#  'stars': '张国荣,张丰毅,巩俐',
#  'score': 9.5,
#  'release_time': '1993-01-01',
#  'img_url': 'https://p1.meituan.net/movie/20803f59291c47e1e116c11963ce019e68711.jpg'}

# %%
mongo.top_100.drop()
mongo.top_100.insert_many(list_to_mongo)

# %%
res_deep_copy[1]
# Out:
# {'ranking': 1,
#  'title': '霸王别姬',
#  'stars': '张国荣,张丰毅,巩俐',
#  'score': 9.5,
#  'release_time': '1993-01-01',
#  'img_url': 'https://p1.meituan.net/movie/20803f59291c47e1e116c11963ce019e68711.jpg',
#  '_id': ObjectId('5d45b09db27ef8d970b32082')}

# %% [markdown]
# ## 从MongoDB获取数据

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", 100)  # 设置显示数据的最大列数，防止出现省略号…，导致数据显示不全
pd.set_option("expand_frame_repr", False)  # 当列太多时不自动换行
# %matplotlib inline
sns.set_style("darkgrid")

# %%
mongo.top_100.find()

# %%
df = pd.DataFrame(mongo.top_100.find()).drop("_id", axis=1)
df.sample(5)
# Out:
#                                               img_url  ranking release_time  score                 stars     title
# 69  https://p1.meituan.net/movie/0b0d45b58946078dd...       70   2015-02-13    9.2            黎明,张曼玉,曾志伟       甜蜜蜜
# 83  https://p0.meituan.net/movie/b5ff0216e689b3fcc...       84   2013-07-31    8.8           河正宇,李璟荣,李大为      恐怖直播
# 50  https://p0.meituan.net/movie/47dd790e19dad72b5...       51   2009-08-04    8.9  爱德华·阿斯纳,乔丹·长井,鲍勃·彼德森     飞屋环游记
# 55  https://p0.meituan.net/movie/34998e31c6d07475f...       56   2012-11-22    9.1       苏拉·沙玛,伊尔凡·可汗,塔布  少年派的奇幻漂流
# 99  https://p0.meituan.net/movie/30b20139e68c46d02...      100   2019-06-21    9.3          柊瑠美,周冬雨,入野自由      千与千寻

# %% [markdown]
# ### 电影9分以上的电影有哪些 取Top10

# %%
def top_10_upper_9(mongo, score):
    query = {"score": {"$gte": score}}
    res = mongo.top_100.find(query).limit(10)
    return pd.DataFrame(res).drop("_id", axis=1)


top_10_upper_9(mongo, 9.0)
# Out:
#                                              img_url  ranking release_time  score                     stars    title
# 0  https://p1.meituan.net/movie/20803f59291c47e1e...        1   1993-01-01    9.5                张国荣,张丰毅,巩俐     霸王别姬
# 1  https://p0.meituan.net/movie/283292171619cdfd5...        2   1994-09-10    9.5       蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿   肖申克的救赎
# 2  https://p0.meituan.net/movie/289f98ceaa8a0ae73...        3   1953-09-02    9.1     格利高里·派克,奥黛丽·赫本,埃迪·艾伯特     罗马假日
# 3  https://p1.meituan.net/movie/6bea9af4524dfbd0b...        4   1994-09-14    9.5       让·雷诺,加里·奥德曼,娜塔莉·波特曼  这个杀手不太冷
# 4  https://p1.meituan.net/movie/b607fba7513e7f15e...        5   1998-04-03    9.5  莱昂纳多·迪卡普里奥,凯特·温丝莱特,比利·赞恩    泰坦尼克号
# 5  https://p0.meituan.net/movie/da64660f82b98cdc1...        6   1993-07-01    9.1                周星驰,巩俐,郑佩佩   唐伯虎点秋香
# 6  https://p0.meituan.net/movie/46c29a8b8d8424bdd...        7   1940-05-17    9.2       费雯·丽,罗伯特·泰勒,露塞尔·沃特森     魂断蓝桥
# 7  https://p0.meituan.net/movie/223c3e186db3ab4ea...        8   1939-12-15    9.1     费雯·丽,克拉克·盖博,奥利维娅·德哈维兰     乱世佳人
# 8  https://p1.meituan.net/movie/ba1ed511668402605...        9   1992-01-01    9.1            寺田农,鹫尾真知子,龟山助清     天空之城
# 9  https://p0.meituan.net/movie/b0d986a8bf89278af...       10   1993-12-15    9.2       连姆·尼森,拉尔夫·费因斯,本·金斯利   辛德勒的名单

# %% [markdown]
# ### 2010年以后的电影有哪些

# %%
def after_date(mongo, date):
    query = {'release_time': {"$gt": date}}
    res = mongo.top_100.find(query).limit(10)
    return pd.DataFrame(res).drop("_id", axis=1)


after_date(mongo, "2010")
# Out:
#                                              img_url  ranking release_time  score                      stars      title
# 0  https://p0.meituan.net/movie/7787c10ad5e95b03c...       35   2010-03-12    9.3          Forest,理查·基尔,琼·艾伦    忠犬八公的故事
# 1  https://p1.meituan.net/movie/bc022b86345c643ca...       36   2013-04-20    9.5       尼古拉斯·凯奇,艾玛·斯通,瑞安·雷诺兹      疯狂原始人
# 2  https://p1.meituan.net/movie/2f344a9f9575edbca...       37   2010-09-01    9.2  莱昂纳多·迪卡普里奥,渡边谦,约瑟夫·高登-莱维特       盗梦空间
# 3  https://p1.meituan.net/movie/91f575ec93f019f42...       40   2010-01-04    9.0   萨姆·沃辛顿,佐伊·索尔达娜,米歇尔·罗德里格兹        阿凡达
# 4  https://p0.meituan.net/movie/b0d97e4158b47d653...       46   2010-05-14    9.0   杰伊·巴鲁切尔,杰拉德·巴特勒,亚美莉卡·费雷拉       驯龙高手
# 5  https://p0.meituan.net/movie/845ce32778a1b3f25...       47   2011-05-12    9.2          范·迪塞尔,保罗·沃克,道恩·强森     速度与激情5
# 6  https://p0.meituan.net/movie/85c2bfba6025bfbfb...       50   2010-07-09    9.0     史蒂夫·卡瑞尔,杰森·席格尔,拉塞尔·布兰德       神偷奶爸
# 7  https://p1.meituan.net/movie/ca4a128a5a54d5b5e...       53   2011-12-08    9.1            阿米尔·汗,黄渤,卡琳娜·卡普    三傻大闹宝莱坞
# 8  https://p0.meituan.net/movie/34998e31c6d07475f...       56   2012-11-22    9.1            苏拉·沙玛,伊尔凡·可汗,塔布   少年派的奇幻漂流
# 9  https://p0.meituan.net/movie/92eb862c42c49f8e4...       59   2014-10-24    9.6                周星驰,莫文蔚,吴孟达  大话西游之月光宝盒

# %% [markdown]
# ### 查询某个明星的电影有哪些

# %%
def actors_movies(mongo, actor):
    query = {"stars": {"$in": [actor]}}
    query = {"stars": {'$regex': actor}}
    res = mongo.top_100.find(query)
    return pd.DataFrame(res).drop("_id", axis=1)


actors_movies(mongo, "张国荣")
# Out:
#                                                                     img_url  ranking release_time  score        stars       title
# 0    https://p1.meituan.net/movie/20803f59291c47e1e116c11963ce019e68711.jpg        1   1993-01-01    9.5   张国荣,张丰毅,巩俐        霸王别姬
# 1    https://p0.meituan.net/movie/ae7245920d95c03765fe1615f3a1fe3865785.jpg       14   1997-05-30    9.2   张国荣,梁朝伟,张震        春光乍泄
# 2   https://p1.meituan.net/movie/53b6f0b66882a53b08896c92076515a8236400.jpg       24   1993-02-05    8.9  张国荣,梁朝伟,张学友  射雕英雄传之东成西就
# 3   https://p1.meituan.net/movie/7e471a9171a410ebc9413b2f1de67afc130067.jpg       39   1994-09-17    8.8  张国荣,梁朝伟,刘嘉玲        东邪西毒
# 4   https://p1.meituan.net/movie/96d98200d2afb4b87ff189f9c15b6545568339.jpg       65   2011-04-30    9.2   张国荣,王祖贤,午马        倩女幽魂
# 5   https://p0.meituan.net/movie/3e5f5f3aa4b7e5576521e26c2c7c894d253975.jpg       92   2017-11-17    9.2   狄龙,张国荣,周润发        英雄本色
# 6  https://p0.meituan.net/movie/885fc379c614a2b4175587b95ac98eb95045650.jpg       93   2018-06-25    8.8  张国荣,张曼玉,刘德华        阿飞正传

# %% [markdown]
# ## mongo_main.py

# %%
# %load mongo_main.py
from top_100 import crawling_movies
from pymongo import MongoClient
import pandas as pd
import pprint
import copy

pd.set_option("display.max_columns", 100)  # 设置显示数据的最大列数，防止出现省略号…，导致数据显示不全
pd.set_option("expand_frame_repr", False)  # 当列太多时不自动换行
pd.set_option('max_colwidth', 255)  # 单元格最大数据长度

def load_config():
    import json
    with open("config.json") as config:
        return json.load(config) 
    
def mongo_db(db_name):
    client = MongoClient(f'{load_config()["host"]}:27017')
    mongo = client[db_name]
    return mongo


def data_to_mongo(mongo):
    mongo.top_100.drop()
    res = crawling_movies()
    res_deep_copy = copy.deepcopy(res)
    list_to_mongo = [res_deep_copy[i] for i in res_deep_copy]
    mongo.top_100.insert_many(list_to_mongo)


def top_10_upper_9(mongo, score):
    query = {"score": {"$lte": score}}
    projection = {"_id": 0}
    res = mongo.top_100.find(query, projection)
    return [i for i in res]


def after_date(mongo, date):
    query = {'release_time': {"$lt": date}}
    res = mongo.top_100.find(query)
    return [i for i in res]


def actors_movies(mongo, actor):
    query = {"stars": {"$exists": actor}}
    res = mongo.top_100_json.find(query)
    return [i for i in res]


if __name__ == "__main__":
    # 建立连接
    mongo = mongo_db('maoyan')
    # 数据入库
    # data_to_mongo(mongo)
    # 查询数据

    top_100s = mongo.top_100.find()
    pprint.pprint(top_100s)

    # 修改为DataFrame可以查看的格式
    df = pd.DataFrame(top_100s).drop("_id", axis=1)
    print(df)

    print('电影9分以上的电影有哪些 取Top10')
    pprint.pprint(top_10_upper_9(mongo, 9.0))
    print('2010年以后的电影有哪些')
    pprint.pprint(after_date(mongo, '2010-01-01'))
    print('查询张国荣的电影有哪些')
    pprint.pprint(actors_movies(mongo, '张国荣'))
    pprint.pprint([i for i in mongo.top_100.find({'1': {}})])
